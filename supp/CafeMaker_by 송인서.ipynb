# %%
import pygame
import time
import sys
import random

pygame.init()


white = (247, 218, 217)

buttonImg = pygame.image.load("images/button.png")
fruit_icon = pygame.image.load("images/fruit_icon.png")
milk_icon = pygame.image.load("images/milk_icon.png")
coffee_icon = pygame.image.load("images/coffee_icon.png")
powder_icon = pygame.image.load("images/powder_icon.png")
syrup_icon = pygame.image.load("images/syrup_icon.png")

category_img = pygame.image.load("images/category.png")
Xbutton_img = pygame.image.load("images/Xbutton.png")



display_width = 800
display_height = 700
gameDisplay = pygame.display.set_mode((display_width, display_height))
pygame.display.set_caption("Cafe Maker")

clock = pygame.time.Clock()



class Button:
    def __init__(self, img_in, x, y, width, height, img_act, x_act, y_act, action = None, icon = None, name = None):
        mouse = pygame.mouse.get_pos()
        click = pygame.mouse.get_pressed()
        if name != None:
            font = pygame.font.Font('DungGeunMo.ttf',20)
            text_name = font.render(name,True,(255,255,255))
            text_Rect = text_name.get_rect()
            text_Rect.centerx = round(x + width)
            text_Rect.y = y + height + 40
            gameDisplay.blit(text_name, text_Rect)
        if x + width >mouse[0] > x and y + height > mouse[1] > y:
            gameDisplay.blit(img_act,(x_act, y_act))
            if click[0]:
                action()
                time.sleep(0.5)
        elif icon == None:
            gameDisplay.blit(img_in,(x,y))
        elif icon != None:
            gameDisplay.blit(img_in,(x,y))
            gameDisplay.blit(icon,(x+16,y+15))


class Ingredient:
    Add_Count = 0
    def __init__(self):
        self.count = 0
        self.name = str(self)
    def Add(self):
        Ingredient.Add_Count = Ingredient.Add_Count + 1
        self.count = self.count + 1
    def Reset():
        Ingredient.Add_Count = 0

        
def popup_text(x,y,text,size, RGB):
    font = pygame.font.Font('DungGeunMo.ttf',size)
    text_pop = font.render(text,True,RGB)
    text_Rect = text_pop.get_rect()
    text_Rect.centerx = round(x)
    text_Rect.y = y
    gameDisplay.blit(text_pop, text_Rect)

def quitgame():
    pygame.quit()
    sys.exit()

select_1 = False
select_2 = False
select_3 = False
select_4 = False
select_5 = False
select_6 = False

def FruitCategoryScreen():
    global select_1
    select_1 = True

def MilkCategoryScreen():
    global select_2
    select_2 = True
    """
    while select:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                quitgame()
        gameDisplay.fill(white)
        Button_milk = Button(buttonImg,20,120,100,100,buttonImg,20,120,MilkCategoryScreen,milk_icon,None)
        gameDisplay.blit(category_img,(130,20))
        Button_X = Button(Xbutton_img,650,20,60,60,Xbutton_img,650,20,playScreen,None,None)
        milk = Button(pygame.image.load("images/milk.png"),150,40,100,100,pygame.image.load("images/milk.png"),155,45,add우유,None,"우유")
        water = Button(pygame.image.load("images/water.png"),250,40,100,100,pygame.image.load("images/water.png"),255,45,add물,None,"물")
        coffee = Button(pygame.image.load("images/coffee.png"),350,40,100,100,pygame.image.load("images/coffee.png"),355,45,add커피,None,"커피")
        pygame.display.update()
        """
    
def CoffeeCategoryScreen():
    global select_3
    select_3 = True      

def PowderCategoryScreen():
    global select_4
    select_4 = True          
    
def SyrupCategoryScreen():
    global select_5
    select_5 = True     
    
def CheckScreen():
    global select_6
    select_6 = True
    
물 = Ingredient()
우유  = Ingredient()
커피 = Ingredient()
헤이즐넛시럽 = Ingredient()
바닐라시럽 = Ingredient()
캐러멜시럽 = Ingredient()
딸기 = Ingredient()
블루베리 = Ingredient()
파인애플 = Ingredient()
요거트파우더 = Ingredient()
Add_list = []

def add물():
    global 물
    물.Add()
    Add_list.append('물')
    print(물.count)
    print(Ingredient.Add_Count)
    
def add우유():
    global 우유
    우유.Add()
    Add_list.append('우유')
    print(우유.count)
    
def add커피():
    global 커피
    커피.Add()
    Add_list.append('커피')
    print(커피.count)
    
def add헤이즐넛시럽():
    global 헤이즐넛시럽
    헤이즐넛시럽.Add()
    Add_list.append('헤이즐넛 시럽')
    print(헤이즐넛시럽.count)
    
def add바닐라시럽():
    global 바닐라시럽
    바닐라시럽.Add()
    Add_list.append('바닐라 시럽')
    print(바닐라시럽.count)
    
def add캐러멜시럽():
    global 캐러멜시럽
    캐러멜시럽.Add()
    Add_list.append('캐러멜 시럽')
    print(캐러멜시럽.count)
    
def add딸기():
    global 딸기
    딸기.Add()
    Add_list.append('딸기')
    print(딸기.count)
    
def add블루베리():
    global 블루베리
    블루베리.Add()
    Add_list.append('블루베리')
    print(블루베리.count)
    
    
def add파인애플():
    global 파인애플
    파인애플.Add()
    Add_list.append('파인애플')
    print(파인애플.count)    
    
    
def add요거트파우더():
    global 요거트파우더
    요거트파우더.Add()
    Add_list.append('요거트파우더')
    print(요거트파우더.count)    
    
    
    
def restIng():
    global 물
    global 우유
    global 커피
    global 헤이즐넛시럽
    global 바닐라시럽
    global 캐러멜시럽
    global 딸기
    global 블루베리
    global 파인애플
    global 요거트파우더
    global Add_list
    물 = Ingredient()
    우유  = Ingredient()
    커피 = Ingredient()
    헤이즐넛시럽 = Ingredient()
    바닐라시럽 = Ingredient()
    캐러멜시럽 = Ingredient()
    딸기 = Ingredient()
    블루베리 = Ingredient()
    파인애플 = Ingredient()
    요거트파우더 = Ingredient()
    Ingredient.Reset()
    Add_list = []
    
    
menus = ["아메리카노","카페라떼","바닐라 라떼", "헤이즐넛 라떼","카라멜마끼야또","딸기 요거트 스무디","블루베리 요거트 스무디","파인애플 요거트 스무디","플레인 요거트 스무디"]        
need_menu = menus[random.randrange(0,len(menus))]
score = 0
def Complete():
    global need_menu
    global 물
    global 우유
    global 커피
    global 헤이즐넛시럽
    global 바닐라시럽
    global 캐러멜시럽
    global 딸기
    global 블루베리
    global 파인애플
    global 요거트파우더
    global score
    score = score + 1
    if(need_menu == "아메리카노" and 물.count == 1 and 커피.count ==1 and Ingredient.Add_Count == 2):
        need_menu = menus[random.randrange(0,len(menus))]
        restIng()
        Ingredient.Add_Count = 0
    elif(need_menu == "카페라떼" and 우유.count == 1 and 커피.count ==1 and Ingredient.Add_Count ==2):
        need_menu = menus[random.randrange(0,len(menus))]
        restIng()
        Ingredient.Add_Count = 0
    elif(need_menu == "헤이즐넛 라떼" and 우유.count == 1 and 커피.count ==1 and 헤이즐넛시럽.count ==1 and Ingredient.Add_Count ==3):
        need_menu = menus[random.randrange(0,len(menus))]
        restIng()
        Ingredient.Add_Count = 0
    elif(need_menu == "바닐라 라떼" and 우유.count == 1 and 커피.count ==1 and 바닐라시럽.count ==1 and Ingredient.Add_Count ==3):
        need_menu = menus[random.randrange(0,len(menus))]
        restIng()
        Ingredient.Add_Count = 0
    elif(need_menu == "카라멜마끼야또" and 우유.count == 1 and 커피.count ==1 and 캐러멜시럽.count ==1 and Ingredient.Add_Count ==3):
        need_menu = menus[random.randrange(0,len(menus))]
        restIng()
        Ingredient.Add_Count = 0    
    elif(need_menu == "딸기 요거트 스무디" and 우유.count == 1 and 딸기.count ==1 and 요거트파우더.count ==1 and Ingredient.Add_Count ==3):
        need_menu = menus[random.randrange(0,len(menus))]
        restIng()
        Ingredient.Add_Count = 0     
    elif(need_menu == "블루베리 요거트 스무디" and 우유.count == 1 and 블루베리.count ==1 and 요거트파우더.count ==1 and Ingredient.Add_Count ==3):
        need_menu = menus[random.randrange(0,len(menus))]
        restIng()
        Ingredient.Add_Count = 0     
    elif(need_menu == "파인애플 요거트 스무디" and 우유.count == 1 and 파인애플.count ==1 and 요거트파우더.count ==1 and Ingredient.Add_Count ==3):
        need_menu = menus[random.randrange(0,len(menus))]
        restIng()
        Ingredient.Add_Count = 0     
    elif(need_menu == "플레인 요거트 스무디" and 우유.count == 1 and 요거트파우더.count ==1 and Ingredient.Add_Count ==2):
        need_menu = menus[random.randrange(0,len(menus))]
        restIng()
        Ingredient.Add_Count = 0     
    else : score = score - 1                 
        
def playScreen():
    global select_1
    global select_2
    global select_3
    global select_4
    global select_5
    global select_6
    select_1 = False
    select_2 = False
    select_3 = False
    select_4 = False
    select_5 = False
    select_6 = False
    play = True
    while play:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()

        gameDisplay.fill(white)
        gameDisplay.blit(pygame.image.load("images/background.png"),(20,0))
        
        Button_fruit = Button(buttonImg,20,20,100,100,buttonImg,20,20,FruitCategoryScreen,fruit_icon,None)
        Button_milk = Button(buttonImg,20,120,100,100,buttonImg,20,120,MilkCategoryScreen,milk_icon,None)
        Button_coffee = Button(buttonImg,20,220,100,100,buttonImg,20,220,CoffeeCategoryScreen,coffee_icon,None)
        Button_powder = Button(buttonImg,20,320,100,100,buttonImg,20,320,PowderCategoryScreen,powder_icon,None)
        Button_syrup = Button(buttonImg,20,420,100,100,buttonImg,20,420,SyrupCategoryScreen,syrup_icon,None)
        Button_reset = Button(buttonImg,700,20,100,100,buttonImg,700,20,restIng,pygame.image.load("images/reset.png"),None)
        Button_check = Button(buttonImg,700,120,100,100,buttonImg,700,120,CheckScreen,pygame.image.load("images/search.png"),None)
        
        Button_complete = Button(pygame.image.load("images/Complete.png"),275,470,200,100,pygame.image.load("images/CompleteP.png"),275,470,Complete,None,None)
        font1 = pygame.font.Font('DungGeunMo.ttf',60)
        font2 = pygame.font.Font('DungGeunMo.ttf',30)
        font3 = pygame.font.Font('DungGeunMo.ttf',40)
        text_comp = font1.render("완성!",True,(255,245,234))
        text_score = font2.render("점수 : " + str(score),True,(51,204,51))
        text_menu = font3.render("주문 : "+need_menu,True,(0,0,0))
        gameDisplay.blit(text_comp,(340,500))
        gameDisplay.blit(text_score,(620,600))
        text_Rect = text_menu.get_rect()
        text_Rect.centerx = round(display_width / 2)
        text_Rect.y = 50
        gameDisplay.blit(text_menu, text_Rect)
        
        
        if(select_1 == True):
            gameDisplay.blit(category_img,(130,20))
            Button_X = Button(Xbutton_img,650,20,60,60,Xbutton_img,650,20,playScreen,None,None)
            strawberry = Button(pygame.image.load("images/strawberry.png"),150,40,100,100,pygame.image.load("images/strawberry.png"),155,45,add딸기,None,"딸기")
            pineapple = Button(pygame.image.load("images/pineapple.png"),250,40,100,100,pygame.image.load("images/pineapple.png"),255,45,add파인애플,None,"파인애플")
            blueberry = Button(pygame.image.load("images/blueberry.png"),350,40,100,100,pygame.image.load("images/blueberry.png"),355,45,add블루베리,None,"블루베리")
             
            pygame.display.update()
        if(select_2 == True):
            gameDisplay.blit(category_img,(130,20))
            Button_X = Button(Xbutton_img,650,20,60,60,Xbutton_img,650,20,playScreen,None,None)
            milk = Button(pygame.image.load("images/milk.png"),150,40,100,100,pygame.image.load("images/milk.png"),155,45,add우유,None,"우유")
            water = Button(pygame.image.load("images/water.png"),250,40,100,100,pygame.image.load("images/water.png"),255,45,add물,None,"물")
            pygame.display.update()
        if(select_3 == True):
            gameDisplay.blit(category_img,(130,20))
            Button_X = Button(Xbutton_img,650,20,60,60,Xbutton_img,650,20,playScreen,None,None)
            coffee = Button(pygame.image.load("images/coffee.png"),150,40,100,100,pygame.image.load("images/coffee.png"),155,45,add커피,None,"커피")
            pygame.display.update()    
        if(select_4 == True):
            gameDisplay.blit(category_img,(130,20))
            Button_X = Button(Xbutton_img,650,20,60,60,Xbutton_img,650,20,playScreen,None,None)
            yogurtpowder = Button(pygame.image.load("images/yogurtpowder.png"),150,40,100,100,pygame.image.load("images/yogurtpowder.png"),155,45,add요거트파우더,None,"요거트 파우더")
            pygame.display.update()     
        if(select_5 == True):
            gameDisplay.blit(category_img,(130,20))
            Button_X = Button(Xbutton_img,650,20,60,60,Xbutton_img,650,20,playScreen,None,None)
            hazlenut_syrup = Button(pygame.image.load("images/hazelnutsyrup.png"),150,40,100,100,pygame.image.load("images/hazelnutsyrup.png"),155,45,add헤이즐넛시럽,None,"헤이즐넛 시럽")
            vanilla_syrup = Button(pygame.image.load("images/vanillasyrup.png"),150,190,100,100,pygame.image.load("images/vanillasyrup.png"),155,195,add바닐라시럽,None,"바닐라 시럽")
            caramel_syrup = Button(pygame.image.load("images/caramelsyrup.png"),150,340,100,100,pygame.image.load("images/caramelsyrup.png"),155,345,add캐러멜시럽,None,"캐러멜 시럽")
            pygame.display.update()
        if(select_6 == True):
            gameDisplay.blit(category_img,(130,20))
            Button_X = Button(Xbutton_img,50,20,60,60,Xbutton_img,50,20,playScreen,None,None)
            for a in range(0, len(Add_list)):
                font_a = pygame.font.Font('DungGeunMo.ttf',30)
                text_a = font_a.render(Add_list[a],True,(255,245,234))
                gameDisplay.blit(text_a,(200,50 + a*40))
            pygame.display.update()
        
        pygame.display.update()
        clock.tick(15)
        
def TitleScreen():
    play = True
    while play:
        for event in pygame.event.get():
            if event.type == pygame.QUIT:
                pygame.quit()
                sys.exit()

        gameDisplay.fill(white)
        gameDisplay.blit(pygame.image.load("images/hot.png"),(140,-200))
        
        
        
        font2 = pygame.font.Font('DungGeunMo.ttf',160)
        text_title3 = font2.render("Coffee",True,(250,255,255))
        text_title4 = font2.render("Maker",True,(255,255,255))
        text_Rect3 = text_title3.get_rect()
        text_Rect3.centerx = round(400)
        text_Rect3.y = 150
        gameDisplay.blit(text_title3, text_Rect3)
        text_Rect4 = text_title4.get_rect()
        text_Rect4.centerx = round(400)
        text_Rect4.y = 250
        gameDisplay.blit(text_title4, text_Rect4)
        
        Button_complete = Button(pygame.image.load("images/Complete.png"),275,470,200,100,pygame.image.load("images/CompleteP.png"),275,470,playScreen,None,None)
        font = pygame.font.Font('DungGeunMo.ttf',60)
        text_comp = font.render("시작",True,(255,245,234))
        gameDisplay.blit(text_comp,(340,500))
        
        font = pygame.font.Font('DungGeunMo.ttf',150)
        text_title1 = font.render("Coffee",True,(150,140,131))
        text_title2 = font.render("Maker",True,(150,140,131))
        text_Rect1 = text_title1.get_rect()
        text_Rect1.centerx = round(400)
        text_Rect1.y = 150
        gameDisplay.blit(text_title1, text_Rect1)
        text_Rect2 = text_title2.get_rect()
        text_Rect2.centerx = round(400)
        text_Rect2.y = 250
        gameDisplay.blit(text_title2, text_Rect2)
        
        

        
        pygame.display.update()
        clock.tick(15)        

TitleScreen()
#playScreen()
game_loop()
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# 1
# 1
# 1
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\insue\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3426: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
